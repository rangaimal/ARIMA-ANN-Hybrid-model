# %%
2+2
# Out:
# 4

# %% [markdown]
# # heading 1

# %%
import pandas as pd

# %%
data1 = pd.read_excel('C:/Users/Acer/Desktop/Research/Market indices monthly.xlsx', header = 0)

# %%
data1.head(10)
# Out:
#                   Date     ASPI SPI / MPI (Jan-99 onwards)  S&P SL 20  \
# 0  1994-01-31 00:00:00  1127.17                    1734.43        NaN
# 1  1994-02-28 00:00:00  1375.12                    2093.75        NaN
# 2  1994-03-31 00:00:00  1190.33                    1755.91        NaN
# 3  1994-04-29 00:00:00  1050.85                    1555.88        NaN
# 4  1994-05-31 00:00:00  1014.93                    1479.04        NaN
# 5  1994-06-30 00:00:00   981.73                    1458.04        NaN
# 6  1994-07-29 00:00:00   976.47                    1455.12        NaN
# 7  1994-08-31 00:00:00  1048.58                    1537.13        NaN
# 8  1994-09-30 00:00:00  1143.23                    1682.63        NaN
# 9  1994-10-31 00:00:00  1093.65                    1600.98        NaN
#
#    'TURNOVER- Rs Mn Equity  MARKET CAP.- RS. BN.  SHARES -'000  TRADES  \
# 0              4500.270118            145.684375     67250.243   43486
# ...
