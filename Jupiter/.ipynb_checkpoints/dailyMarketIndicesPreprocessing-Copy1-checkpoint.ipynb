# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML, display_html

# %%
df = pd.read_excel(r'C:/Users/Acer/Desktop/Research/Market indices DailyOneSector.xlsx', header =0)

# %%
df.head()
# Out:
#         Date   ASPI  Banks_finance_insurance
# 0 1985-01-02  96.09                    84.88
# 1 1985-01-03  96.08                    85.07
# 2 1985-01-04  96.05                    85.07
# 3 1985-01-07  96.18                    86.82
# 4 1985-01-08  96.34                    87.58

# %%
df.shape
# Out:
# (7713, 24)

# %%
df.dtypes
# Out:
# Date                       datetime64[ns]
# ASPI                              float64
# Banks_finance_insurance           float64
# dtype: object

# %%
df.describe()
# Out:
#               ASPI  Banks_finance_insurance
# count  7713.000000              7713.000000
# mean   2114.644262              4762.152725
# std    2348.320143              5654.315683
# min      96.050000                84.880000
# 25%     509.800000              1055.140000
# 50%     797.360000              2086.980000
# 75%    2681.270000              5040.870000
# max    7811.800000             19828.660000

# %%
# check the time period start data and end date

# %%
print('Time period start: {}\nTime period end: {}'.format(df.Date.min(),df.Date.max()))
# Out:
# Time period start: 1985-01-02 00:00:00
# Time period end: 2017-03-31 00:00:00

# %%
y = df.set_index('Date')

# %%
y.index
# Out:
# DatetimeIndex(['1985-01-02', '1985-01-03', '1985-01-04', '1985-01-07',
#                '1985-01-08', '1985-01-09', '1985-01-10', '1985-01-11',
#                '1985-01-15', '1985-01-16',
#                ...
#                '2017-03-20', '2017-03-21', '2017-03-22', '2017-03-23',
#                '2017-03-24', '2017-03-27', '2017-03-28', '2017-03-29',
#                '2017-03-30', '2017-03-31'],
#               dtype='datetime64[ns]', name='Date', length=7713, freq=None)

# %%
# check the sum of null values of each column.  now y is date

# %%
y.isnull().sum()
# Out:
# ASPI                       0
# Banks_finance_insurance    0
# dtype: int64

# %%
# plot each and every column values with date

# %%
y.plot(figsize=(15, 10))
plt.show()

# %%
# next get idea about the structure of the data we review plots of the desnsity of observations

# %%
from pandas import Series
from matplotlib import pyplot
pyplot.figure(1)
pyplot.subplot(211)
# second raw 1st column 1st number plot
# plot histogram with time and ASPI value
y.ASPI.hist()

# %%
pyplot.subplot(212)
y.ASPI.plot(kind='kde')
pyplot.show()

# %%
# Next check the correlation coefficient between the variables to check tha relationship. negative correlation variables are removed

# %%
df.corr()
# Out:
#                              ASPI  Banks_finance_insurance
# ASPI                     1.000000                 0.992964
# Banks_finance_insurance  0.992964                 1.000000

# %%
#Decomposing using statsmodel
#With statsmodels we will be able to see the trend, seasonal, and residual components of our data.
# Using rcparams we can customize matpoltlib properties

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition1 = sm.tsa.seasonal_decompose(df['Banks_finance_insurance'], model='multiplicative',freq=1000)
decomposition2 = sm.tsa.seasonal_decompose(df['ASPI'], model='multiplicative',freq=1000)
# In here without frequency get valuerror You must specify a freq or x must be a pandas object with a timeseries index
# you can give any value as a frequency.
fig = decomposition1.plot()
fig = decomposition2.plot()
plt.show()

# %%
# next check the Stationarity of time series. if data set is have Stationarity we can't use time series forecasting models for
# that time series. stationarity means statistical properties such as mean, variance remain constant over time.

# %%
plt.plot(y)
# Out:
# [<matplotlib.lines.Line2D at 0x2225d0e63c8>,
#  <matplotlib.lines.Line2D at 0x2225d775c88>]

# %%
# data set have no constant values so we can use timeseries forecasting methods

# %%
# now use ACF and PACF plots to check the stationarity

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
pyplot.figure()
pyplot.subplot(211)
plot_acf(y.ASPI, ax=pyplot.gca(), lags = 30)
pyplot.subplot(212)
plot_pacf(y.ASPI, ax=pyplot.gca(), lags = 30)
pyplot.show()

# %%
pyplot.subplot(211)
plot_acf(y.Banks_finance_insurance, ax=pyplot.gca(), lags = 30)
pyplot.subplot(212)
plot_pacf(y.Banks_finance_insurance, ax=pyplot.gca(), lags = 30)
pyplot.show()

# %%
#if the time series is stationary, the ACF/PACF plots will show a quick drop-off in 
#correlation after a small amount of lag between points.

# %%
pyplot.subplot(211)
plot_acf(y.Berverage_Food_tobacco, ax=pyplot.gca(), lags = 30)
pyplot.subplot(212)
plot_pacf(y.Berverage_Food_tobacco, ax=pyplot.gca(), lags = 30)
pyplot.show()

# %%
# like these we can do for each and every sector in stock maket.

# %%
#Plotting Rolling Statistics
#We observe that the rolling mean and Standard deviation are not constant with respect to time (increasing trend)
#The time series is hence not stationary
# Augmented Dicky-Fuller test
# This is doing also for check the data set is stationary or non-stationary
# And next we get this dicky fuller test $ rolling to a function for a further use

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(df_ts):
    """
    Test stationarity using moving average statistics and Dickey-Fuller test
    Source: https://www.analyticsvidhya.com/blog/2016/02/time-series-forecasting-codes-python/
    """
    
    # Determing rolling statistics
    rolmean = df_ts.rolling(window = 12, center = False).mean()
    rolstd = df_ts.rolling(window = 12, center = False).std()
    
    # Plot rolling statistics:
    orig = plt.plot(df_ts, 
                    color = 'blue', 
                    label = 'Original')
    mean = plt.plot(rolmean, 
                    color = 'red', 
                    label = 'Rolling Mean')
    std = plt.plot(rolstd, 
                   color = 'black', 
                   label = 'Rolling Std')
    plt.legend(loc = 'best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.xticks(rotation = 45)
    plt.show(block = False)
    plt.close()
    
    # Perform Dickey-Fuller test:
    # Null Hypothesis (H_0): time series is not stationary
    # Alternate Hypothesis (H_1): time series is stationary
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(df_ts, 
                      autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], 
                         index = ['Test Statistic',
                                  'p-value',
                                  '# Lags Used',
                                  'Number of Observations Used'])
    
    if (dftest[1]>0.05):
        print("The time series is NOT stationary at the p = 0.05 level.")
    else:
        print("The time series is stationary at the p = 0.05 level.")
                    
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
# if test stastic < critical value it means data set is stationary 
# # if test stastic > critical value it means data set is non-stationary
# in here dataset is non-sationary

# %%
ts=df['ASPI']  # We can use this to every column
test_stationarity(ts)
# Out:
# Results of Dickey-Fuller Test:
# The time series is NOT stationary at the p = 0.05 level.
# Test Statistic                   -0.064371
# p-value                           0.952874
# # Lags Used                      34.000000
# Number of Observations Used    7678.000000
# Critical Value (1%)              -3.431202
# Critical Value (5%)              -2.861917
# Critical Value (10%)             -2.566970
# dtype: float64

# %%
#Eliminating trend and seasonality -Log scale transformation 
#  Log scale transformation .We can apply transformation which penalize higher values more than smaller values.
# for that we can get log value

# %%
ts_log = np.log(ts)
plt.plot(ts_log)

# %%
# lets check ASPI column stationarity using previous create function

# %%
# like wise we can do for all columns

# %%
# Techniques to remove Trend-diffrencing
# In this technique, we take the difference of the observation at a particular instant with that at the previous instant.
# First order differencing in Pandas

# %%
ts_log_diff = ts_log - ts_log.shift() # or we can wrote ts_log.ASPI -ts_log.ASPI.shift()
plt.plot(ts_log_diff)

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# The time series is stationary at the p = 0.05 level.
# Test Statistic                -1.728988e+01
# p-value                        5.713254e-30
# # Lags Used                    2.000000e+01
# Number of Observations Used    7.691000e+03
# Critical Value (1%)           -3.431201e+00
# Critical Value (5%)           -2.861916e+00
# Critical Value (10%)          -2.566970e+00
# dtype: float64

# %%
# Techniques to remove Trend - Decomposition: trend, seasonality, residuals
# Here we use Decomposition.

# %%
# Decomposition
# In this approach, both trend and seasonality are modeled separately and the remaining part of the series is returned.

# %%
def plot_decomposition(df, ts, trend, seasonal, residual):
  """
  Plot time series data
  """
  f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15, 5), sharex = True)

  ax1.plot(df[ts], label = 'Original')
  ax1.legend(loc = 'best')
  ax1.tick_params(axis = 'x', rotation = 45)

  ax2.plot(df[trend], label = 'Trend')
  ax2.legend(loc = 'best')
  ax2.tick_params(axis = 'x', rotation = 45)

  ax3.plot(df[seasonal],label = 'Seasonality')
  ax3.legend(loc = 'best')
  ax3.tick_params(axis = 'x', rotation = 45)

  ax4.plot(df[residual], label = 'Residuals')
  ax4.legend(loc = 'best')
  ax4.tick_params(axis = 'x', rotation = 45)
  plt.tight_layout()

  # Show graph
  plt.suptitle('Trend, Seasonal, and Residual Decomposition of %s' %(ts), 
               x = 0.5, 
               y = 1.05, 
               fontsize = 18)
  plt.show()
  plt.close()
  
  return

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, freq = 365) # in here we decompose log values of ASPI. or we can decompose df[ASPI].but best is decompose log value of ASPI

df.loc[:,'trend'] = decomposition.trend
df.loc[:,'seasonal'] = decomposition.seasonal
df.loc[:,'residual'] = decomposition.resid

plot_decomposition(df, 
                   ts = 'ASPI', 
                   trend = 'trend',
                   seasonal = 'seasonal', 
                   residual = 'residual')

display(HTML("<b>The stationarity test of residual:</b>"))
test_stationarity(df.dropna()['residual'])
# Out:
# <b>The stationarity test of residual:</b>
# Results of Dickey-Fuller Test:
# The time series is stationary at the p = 0.05 level.
# Test Statistic                -6.996063e+00
# p-value                        7.528451e-10
# # Lags Used                    2.100000e+01
# Number of Observations Used    7.327000e+03
# Critical Value (1%)           -3.431243e+00
# Critical Value (5%)           -2.861935e+00
# Critical Value (10%)          -2.566980e+00
# dtype: float64

# %%
df[['Date','ASPI']].plot.scatter('Date','ASPI', figsize=(12,10))

# %%
df[['Date','ASPI']].plot('Date', figsize=(12,10))

# %%
np.percentile(df.Banks_finance_insurance,[99])
# Out:
# array([18868.056])

# %%
 np.percentile(df.Banks_finance_insurance,[99])[0]
# Out:
# 18868.056000000004

# %%
uv=np.percentile(df.Banks_finance_insurance,[99])[0]

# %%
df[(df.Banks_finance_insurance>uv)]
# Out:
#            Date     ASPI  Banks_finance_insurance  Berverage_Food_tobacco  \
# 7175 2015-01-08  7497.60                 18936.71                21681.02
# 7176 2015-01-09  7605.79                 19253.56                22142.37
# 7177 2015-01-12  7566.70                 19204.99                22241.73
# 7178 2015-01-13  7549.85                 19154.88                22356.33
# 7179 2015-01-16  7513.86                 19066.97                22168.90
# ...         ...      ...                      ...                     ...
# 7327 2015-08-28  7350.52                 19221.70                22660.94
# 7328 2015-08-31  7306.94                 19146.87                22500.96
# 7329 2015-09-01  7298.75                 19082.35                22452.74
# 7330 2015-09-02  7240.39                 18899.40                22422.01
# 7331 2015-09-03  7245.50                 18870.21                22490.88
#
#       Chemicals_Pharmaceuticals  Construction_Engineering  Footwear_Textile  \
# 7175                    7622.54                   4038.39           1061.57
# 7176                    7684.63                   3949.86           1072.57
# 7177                    7452.26                   3708.92           1052.41
# 7178                    7505.95                   3702.36           1035.44
# 7179                    7384.55                   3689.71           1035.44
# ...                         ...                       ...               ...
# 7327                    8108.17                   3296.76            972.30
# 7328                    8111.56                   3239.16           1002.02
# 7329                    8074.63                   3254.60           1006.96
# 7330                    8027.76                   3237.58           1000.10
# 7331                    8062.68                   3253.83           1008.29
#
#          trend  seasonal  residual
# 7175  8.854933  0.009072  0.058334
# 7176  8.855363  0.008459  0.072842
# 7177  8.855769  0.010390  0.065354
# 7178  8.856165  0.011269  0.061849
# 7179  8.856562  0.008612  0.059331
# ...        ...       ...       ...
# 7327  8.841937 -0.006936  0.067525
# 7328  8.841652 -0.010832  0.065760
# 7329  8.841367 -0.013659  0.067750
# 7330  8.841105 -0.014431  0.060756
# 7331  8.840869 -0.011167  0.058434
#
# [78 rows x 10 columns]

# %%
df.Banks_finance_insurance[(df.Banks_finance_insurance>3*uv)]=3*uv

# %%
 np.percentile(df.ASPI,[1])[0]
# Out:
# 102.74119999999999

# %%
lv=np.percentile(df.ASPI,[1])[0]

# %%
df[(df.ASPI<lv)]
# Out:
#           Date    ASPI  Banks_finance_insurance  Berverage_Food_tobacco  \
# 0   1985-01-02   96.09                    84.88                   88.25
# 1   1985-01-03   96.08                    85.07                   88.25
# 2   1985-01-04   96.05                    85.07                   88.48
# 3   1985-01-07   96.18                    86.82                   88.48
# 4   1985-01-08   96.34                    87.58                   88.48
# ..         ...     ...                      ...                     ...
# 188 1985-10-11  102.54                   100.93                  131.30
# 189 1985-10-14  102.59                   101.14                  131.30
# 190 1985-10-15  102.52                   101.14                  131.30
# 191 1985-10-16  102.52                   101.14                  131.30
# 192 1985-10-17  102.50                   101.22                  131.30
#
#      Chemicals_Pharmaceuticals  Construction_Engineering  Footwear_Textile  \
# 0                        84.79                    124.83            104.95
# 1                        84.79                    124.55            104.95
# 2                        84.79                    124.55            103.84
# 3                        84.32                    124.55            103.84
# 4                        85.41                    124.69            102.73
# ..                         ...                       ...               ...
# 188                     121.15                     48.31             94.01
# 189                     121.15                     48.31             94.01
# 190                     121.15                     48.17             95.12
# 191                     121.15                     48.17             95.12
# 192                     121.15                     48.17             95.12
#
#         trend  seasonal  residual
# 0         NaN -0.021609       NaN
# 1         NaN -0.023639       NaN
# 2         NaN -0.025822       NaN
# 3         NaN -0.026612       NaN
# 4         NaN -0.029763       NaN
# ..        ...       ...       ...
# 188  4.729909 -0.000207 -0.099449
# 189  4.730798  0.004840 -0.104898
# 190  4.731689  0.006908 -0.108538
# 191  4.732607  0.008557 -0.111105
# 192  4.733549  0.014095 -0.117782
#
# [78 rows x 10 columns]

# %%
df.ASPI[(df.ASPI <0.3*lv)]=0.3*lv

# %%
df[(df.ASPI<lv)]
# Out:
#           Date    ASPI  Banks_finance_insurance  Berverage_Food_tobacco  \
# 0   1985-01-02   96.09                    84.88                   88.25
# 1   1985-01-03   96.08                    85.07                   88.25
# 2   1985-01-04   96.05                    85.07                   88.48
# 3   1985-01-07   96.18                    86.82                   88.48
# 4   1985-01-08   96.34                    87.58                   88.48
# ..         ...     ...                      ...                     ...
# 188 1985-10-11  102.54                   100.93                  131.30
# 189 1985-10-14  102.59                   101.14                  131.30
# 190 1985-10-15  102.52                   101.14                  131.30
# 191 1985-10-16  102.52                   101.14                  131.30
# 192 1985-10-17  102.50                   101.22                  131.30
#
#      Chemicals_Pharmaceuticals  Construction_Engineering  Footwear_Textile  \
# 0                        84.79                    124.83            104.95
# 1                        84.79                    124.55            104.95
# 2                        84.79                    124.55            103.84
# 3                        84.32                    124.55            103.84
# 4                        85.41                    124.69            102.73
# ..                         ...                       ...               ...
# 188                     121.15                     48.31             94.01
# 189                     121.15                     48.31             94.01
# 190                     121.15                     48.17             95.12
# 191                     121.15                     48.17             95.12
# 192                     121.15                     48.17             95.12
#
#         trend  seasonal  residual
# 0         NaN -0.021609       NaN
# 1         NaN -0.023639       NaN
# 2         NaN -0.025822       NaN
# 3         NaN -0.026612       NaN
# 4         NaN -0.029763       NaN
# ..        ...       ...       ...
# 188  4.729909 -0.000207 -0.099449
# 189  4.730798  0.004840 -0.104898
# 190  4.731689  0.006908 -0.108538
# 191  4.732607  0.008557 -0.111105
# 192  4.733549  0.014095 -0.117782
#
# [78 rows x 10 columns]

# %%
df.describe()
# Out:
#               ASPI  Banks_finance_insurance  Berverage_Food_tobacco  \
# count  7713.000000              7713.000000             7713.000000
# mean   2114.644262              4762.152725             4632.645135
# std    2348.320143              5654.315683             7086.244385
# min      96.050000                84.880000               63.600000
# 25%     509.800000              1055.140000              522.090000
# 50%     797.360000              2086.980000              787.500000
# 75%    2681.270000              5040.870000             3644.750000
# max    7811.800000             19828.660000            23184.750000
#
#        Chemicals_Pharmaceuticals  Construction_Engineering  Footwear_Textile  \
# count                7713.000000               7713.000000       7713.000000
# mean                 2731.423243                956.915699        536.813469
# std                  3107.026922               1262.125834        379.261823
# min                    80.620000                 48.170000         58.900000
# 25%                   759.890000                181.290000        168.230000
# 50%                  1153.400000                291.740000        534.500000
# 75%                  3182.650000                947.220000        849.560000
# max                 15187.210000               4636.510000       1679.750000
#
#              trend     seasonal     residual
# count  7349.000000  7713.000000  7349.000000
# mean      6.975934    -0.000086     0.000707
# std       1.183160     0.016207     0.100050
# min       4.724627    -0.038253    -0.367705
# 25%       6.279711    -0.011657    -0.055084
# 50%       6.667977     0.002862     0.001867
# 75%       7.838727     0.011815     0.060035
# max       8.871292     0.036121     0.408873

# %%
df.to_csv("df.csv",header=True)
